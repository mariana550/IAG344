# %% [markdown]
# # LIBRERIAS

# %%
import pandas as pd # pip install pandas

# %% [markdown]
# # CARGAR DATOS

# %%
df = pd.read_csv("./dataset.csv") # lee el archivo CSV
df.head(5) # muestra las primeras 5 filas
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 3      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 4     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
df.describe() # estadísticos básicos
# Out:
#                   id   favorites    retweets   mentions   followers  \
# count      27.000000   26.000000   26.000000  26.000000   26.000000
# mean   183734.000000  280.538462   80.000000  15.423077  352.807692
# std         7.937254  153.377242   40.303846   9.596554  375.319493
# min    183721.000000   23.000000   21.000000   1.000000   12.000000
# 25%    183727.500000  139.250000   45.500000   8.250000   21.000000
# 50%    183734.000000  305.500000   79.000000  16.000000  332.000000
# 75%    183740.500000  422.500000  110.750000  23.500000  389.000000
# max    183747.000000  500.000000  146.000000  29.000000  982.000000
#
#          followees
# count    27.000000
# mean   1190.185185
# std    1965.735995
# min     129.000000
# 25%     258.000000
# 50%     351.000000
# 75%    1822.000000
# max    9918.000000

# %%
df["favorites"] # columna favorites
# Out:
# 0      23.0
# 1     500.0
# 2     190.0
# 3     131.0
# 4     113.0
# 5     492.0
# 6     158.0
# 7       NaN
# 8     198.0
# 9     272.0
# 10     43.0
# 11    349.0
# 12    467.0
# 13     50.0
# 14    418.0
# 15    361.0
# 16    346.0
# 17    296.0
# 18    315.0
# 19    133.0
# 20     92.0
# 21    255.0
# 22    432.0
# 23    430.0
# 24    424.0
# 25    488.0
# 26    318.0
# Name: favorites, dtype: float64

# %% [markdown]
# # SE LEE EL ARCHIVO

# %%
df2 = pd.read_excel("C:/Users/ville/IAG344/Mision2/Datos.xlsx")
df2.head(5)
# Out:
#        Cedula    Nombre   Apellido  Cedula_limpia    Nombre_completo
# 0  1055754628  Mariana   Villegas      1055754628  Mariana  Villegas
# 1    23567783      Lupe      Arias       23567783         Lupe Arias
# 2  1890678678   Martina     Garcia     1890678678     Martina Garcia

# %%
df.loc[0] # primera fila
# Out:
# id                                                      183721
# full_text    Flying home to run down from the power to comi...
# favorites                                                 23.0
# retweets                                                   NaN
# mentions                                                  10.0
# country                                                ECUADOR
# user                                             leonardokuffo
# followers                                                389.0
# followees                                                  258
# Name: 0, dtype: object

# %%
df.head() # muestra las primeras 5 filas
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 3      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 4     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# # df.loc[0:2]
# toma los registros desda la ubicacion inicial hasta la ubicacion final
# loc= localizar
# df=data

# %%
df.loc[0:2]
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129

# %%
df.loc[[0,1,7]]
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 7  183728  Thank you guess how did I feel somewhat offend...        NaN
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 7      50.0      10.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# # df.loc[[1,7],["favorites"]]
# se trae la informacion de la columna que se especifique

# %%
df.loc[[1,7],["favorites"]]
# Out:
#    favorites
# 1      500.0
# 7        NaN

# %%
df.loc[:,["favorites"]] # se traen todas las filas y columnas favorites
# Out:
#     favorites
# 1       500.0
# 2       190.0
# 3       131.0
# 4       113.0
# 5       492.0
# 6       158.0
# 7         NaN
# 8       198.0
# 9       272.0
# 10       43.0

# %%
# seleccionar por condicion 
df[df["favorites"] > 400]
# Out:
#         id                                          full_text  favorites  \
# 1   183722                Today we commemorate and MNML Case.      500.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 12  183733                           Programming is the best!      467.0
# 14  183735                             Buy this product NOW!!      418.0
# 22  183743                         Amazing video by Leonardo!      432.0
# 23  183744                                        Thanks man!      430.0
# 24  183745          There is nothing better than programming!      424.0
# 25  183746                                           BORED AF      488.0
#
#     retweets  mentions  country             user  followers  followees
# 1       21.0       NaN   BRASIL    mateusmartins      982.0       1822
# 5       70.0       6.0   BRASIL    mateusmartins      982.0       1822
# 12      69.0      10.0  ECUADOR    leonardokuffo      389.0        258
# ...

# %%
# selecciona y muestra las filas que cumplen las condiciones
df[(df["favorites"] > 400) & (df["mentions"] > 20)]
# Out:
#         id                                  full_text  favorites  retweets  \
# 23  183744                                Thanks man!      430.0     143.0
# 24  183745  There is nothing better than programming!      424.0     110.0
# 25  183746                                   BORED AF      488.0      28.0
#
#     mentions country             user  followers  followees
# 23      28.0  BRASIL       lucasperes        NaN        351
# 24      29.0  BRASIL       lucasperes       82.0        351
# 25      27.0  MEXICO  gabrielcarvajal       21.0       2721

# %%
df.loc[9:19,] # muestra filas de la 9 a la 19
# Out:
#         id                                          full_text  favorites  \
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
# 13  183734                             I cannot believe this!       50.0
# 14  183735                             Buy this product NOW!!      418.0
# 15  183736  I have one is best color gradients: Just relea...      361.0
# 16  183737                                              PIC!!      346.0
# 17  183738                             hmmm feeling bad today      296.0
# 18  183739                          not feeling god right now      315.0
# 19  183740                        Programming is a hot topic!      133.0
#
#     retweets  mentions  country             user  followers  followees
# ...

# %%
# df[(df["favorites"] > 400) & (df["mentions"] > 20)]
# df.loc[9:19,]

df.loc[9:19,]
df[(df["favorites"] > 400) & (df["mentions"] > 20)]
# Out:
#         id                                  full_text  favorites  retweets  \
# 23  183744                                Thanks man!      430.0     143.0
# 24  183745  There is nothing better than programming!      424.0     110.0
# 25  183746                                   BORED AF      488.0      28.0
#
#     mentions country             user  followers  followees
# 23      28.0  BRASIL       lucasperes        NaN        351
# 24      29.0  BRASIL       lucasperes       82.0        351
# 25      27.0  MEXICO  gabrielcarvajal       21.0       2721
